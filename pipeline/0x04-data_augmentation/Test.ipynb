# %%
# %run 0-main.py

# %%
# %run 1-main.py

# %%
# %run 2-main.py

# %%
# %run 3-main.py

# %%
# %run 4-main.py

# %%
# %run 5-main.py

# %%
# %run 100-main.py
# Out:
# [-0.17497655  0.03426804  0.11530358]
# [-0.17497655  0.03426804  0.11530358]
